# %% [markdown]
# This notebook is to test the branin hoo function

# %%
seed_number = 1234

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import random
random.seed(seed_number)
import copy

# %%
x1_range = np.arange(-5.0, 10.0, 0.02)
x2_range = np.arange(0.0, 15.0, 0.02)

x1_range_len = len(x1_range)
x2_range_len = len(x2_range)

# %%
const_a = 1.0
const_b = 5.1 / (4.0 * np.power(np.pi, 2))
const_c = 5.0 / np.pi
const_r = 6.0
const_s = 10
const_t = 1.0 / (8.0 * np.pi)

def branin_hoo_first_term(x1):
    
    fx = const_s * (1.0 - const_t) * np.cos(x1) + const_s
    
    return fx

def branin_hoo(x1, x2):
    
    fx = branin_hoo_first_term(x1) + const_a * np.power(x2 - const_b * np.power(x1, 2) + const_c * x1 - const_r, 2)
    
    return fx

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

X1_mesh, X2_mesh = np.meshgrid(x1_range, x2_range)

Z_mesh = branin_hoo(X1_mesh, X2_mesh)

ax = plt.axes(projection='3d')
ax.contour3D(X1_mesh, X2_mesh, Z_mesh, 200)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('b-hoo')
# Out:
# Text(0.5, 0, 'b-hoo')

# %% [markdown]
# # sklearn.gaussian_process

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

# %%
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)

# %% [markdown]
# # training

# %%
train_cnt = 10

x1_train = np.random.choice(x1_range, train_cnt)
x2_train = np.random.choice(x2_range, train_cnt)

x_train = np.stack((x1_train, x2_train)).T
y_train = branin_hoo(x1_train, x2_train)

# %%
gp.fit(x_train, y_train)
# Out:
# GaussianProcessRegressor(alpha=1e-10, copy_X_train=True,
#                          kernel=1**2 * RBF(length_scale=10),
#                          n_restarts_optimizer=9, normalize_y=False,
#                          optimizer='fmin_l_bfgs_b', random_state=None)

# %% [markdown]
# # predicting

# %%
test_cnt = 5

test = np.random.rand(test_cnt, 2)
test[:, 0] = np.random.choice(x1_range, test_cnt)
test[:, 1] = np.random.choice(x2_range, test_cnt)

y_pred, sigma = gp.predict(test, return_std=True)
y_true = branin_hoo(test[:, 0], test[:, 1])

# %%
y_true-y_pred
# Out:
# array([ 14.27554683,  30.74051871, -17.23551794,   9.90046441,
#         32.75636682])

# %%
def plot(X1_mesh, X2_mesh, Z_mesh, gp):
    test = np.stack([np.ravel(X1_mesh), np.ravel(X2_mesh)], axis=1)
    y_pred, sigma = gp.predict(test, return_std=True)

    plt.figure(figsize=(10,5))
    plt.subplot(121)
    plt.contour(X1_mesh, X2_mesh, Z_mesh, 200)
    plt.title('True')
    plt.subplot(122)
    plt.contour(X1_mesh, X2_mesh, y_pred.reshape(X1_mesh.shape), 200)
    plt.title('Predicted')

plot(X1_mesh, X2_mesh, Z_mesh, gp)

# %% [markdown]
# # Bayesian optimisation

# %%
bayesopt_steps = 100

bayesopt_x = copy.copy(x_train)
bayesopt_y = copy.copy(y_train)

for i in range(bayesopt_steps):
    
    # Finding a new point (at the moment is random, should change to EI or something different)
    
    x1_new = np.random.choice(x1_range, 1)
    x2_new = np.random.choice(x2_range, 1)
    x_new = np.stack((x1_new, x2_new)).T
    y_new = branin_hoo(x1_new, x2_new)
    
    print(i+1, x_new, y_new)
    
    bayesopt_x = np.vstack((bayesopt_x, x_new))
    
    bayesopt_y = np.append(bayesopt_y, y_new)
   
    gp.fit(bayesopt_x, bayesopt_y)
# Out:
# 1 [[ 5.4  13.94]] [179.09953272]
# 2 [[-1.02  4.18]] [27.82595704]
# 3 [[-3.24  6.5 ]] [36.59747532]
# 4 [[-0.9   7.48]] [15.97202181]
# 5 [[4.58 9.1 ]] [67.70676272]
# 6 [[-0.86  9.14]] [19.07282438]
# 7 [[8.32 8.9 ]] [57.51436117]
# 8 [[-0.06  6.8 ]] [20.08050912]
# 9 [[4.94 3.72]] [18.07010386]
# 10 [[8.92 5.9 ]] [16.17161125]
# 11 [[1.52 0.02]] [25.38183726]
# 12 [[ 1.66 13.18]] [98.74958161]
# 13 [[ 5.08 12.48]] [139.59261544]
# 14 [[-0.78 10.48]] [26.81184399]
# 15 [[-3.48 14.72]] [3.5569438]
# 16 [[4.88 4.22]] [20.07179702]
# 17 [[7.66 6.42]] [37.16485362]
# 18 [[ 1.44 11.98]] [75.3156257]
# 19 [[0.88 1.2 ]] [28.36433622]
# 20 [[ 9.38 13.  ]] [111.9741748]
# 21 [[ 6.56 10.78]] [112.57708837]
# 22 [[4.5  3.76]] [13.29348702]
# 23 [[-4.96  9.86]] [64.36964087]
# 24 [[1.36 9.02]] [36.46777171]
# 25 [[-2.    9.96]] [6.07179604]
# 26 [[-0.8   2.64]] [38.9297354]
# 27 [[4.28 9.64]] [71.34965828]
# 28 [[ 0.6  14.26]] [101.98495016]
# 29 [[-4.86  0.42]] [279.26528401]
# 30 [[-0.04 10.92]] [43.17644345]
# 31 [[-3.52  4.64]] [74.40048264]
# 32 [[4.24 1.06]] [5.89535652]
# 33 [[ 4.7 14.5]] [182.18857881]
# 34 [[-3.06  9.98]] [4.83888003]
# 35 [[-2.48 13.52]] [10.14341481]
# 36 [[0.42 1.24]] [35.69535499]
# 37 [[0.64 1.18]] [32.55761451]
# 38 [[2.28 4.5 ]] [5.87019285]
# 39 [[ 8.86 12.06]] [102.29334493]
# 40 [[-0.78  3.18]] [33.9659084]
# 41 [[7.08 8.88]] [75.58079317]
# 42 [[2.68 2.84]] [1.43430854]
# 43 [[6.62 3.46]] [24.51305797]
# 44 [[-0.86  1.64]] [50.18698499]
# 45 [[6.22 2.26]] [20.93202315]
# 46 [[ 0.52 10.82]] [49.83500934]
# 47 [[-0.26  6.14]] [19.35921186]
# 48 [[4.32 7.18]] [38.18969718]
# 49 [[-4.7  11.12]] [37.06650634]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-8.89054765e+01, -1.79157062e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 62, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# 50 [[ 4.78 11.36]] [110.96790725]
# 51 [[8.8  4.18]] [6.97111363]
# 52 [[4.38 6.94]] [36.38059582]
# 53 [[5.94 7.52]] [60.20351356]
# 54 [[1.6  9.08]] [37.76476833]
# 55 [[ 1.98 10.04]] [50.86624606]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([
-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# 89 [[5.14 4.22]] [22.90749883]
# 90 [[-2.26  7.5 ]] [11.49332752]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.65094677e+02, -7.18213152e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 98, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.65095435e+02,  2.80571467e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.65094731e+02, -2.26369710e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 79, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.65086607e+02, -3.34836129e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 76, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.66070237e+02, -2.09357328e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 56, 'nit': 11, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.66070510e+02, -1.20277303e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 66, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# 91 [[6.72 3.7 ]] [25.26151879]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.66070649e+02, -9.26260738e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 153, 'nit': 22, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-170.49844878,    0.1969705 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# 92 [[ 9.36 14.6 ]] [148.74849109]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.70449420e+02, -6.53934618e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 82, 'nit': 19, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.70441570e+02, -3.94975802e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 66, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.70444615e+02, -2.64009559e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 78, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.70450625e+02, -1.29031659e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 50, 'nit': 7, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-172.63465494,   -0.27831622]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.72688978e+02, -4.33488651e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 85, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# 93 [[-3.76  5.06]] [78.74890555]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.72698489e+02, -2.09115720e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 92, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.72664123e+02, -1.50986187e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 77, 'nit': 8, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.72677607e+02, -9.27450024e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 77, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.72661024e+02, -1.64283489e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 91, 'nit': 16, 'warnflag': 2}
#   ConvergenceWarning)
# 94 [[ 6.06 13.8 ]] [180.67095596]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.76518543e+02, -9.59771284e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 67, 'nit': 22, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.76518525e+02, -1.61636190e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 77, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.76533439e+02,  6.51251849e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 7, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-176.47644481,   -0.18910802]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 73, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.76518680e+02, -7.03284019e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.76518681e+02, -7.62350123e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 64, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# 95 [[-2.06  1.04]] [82.6955857]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-175.77933592,   -9.46006965]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 67, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.78049036e+02, -5.88068295e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 114, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.78050206e+02, -6.84315744e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 70, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-174.70755154,  -13.86319002]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 35, 'nit': 3, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.78012565e+02, -1.58973161e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 65, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# 96 [[3.82 9.36]] [59.59613644]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.79540929e+02, -1.74200977e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 115, 'nit': 8, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.79501527e+02, -1.71133726e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 10, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.79540636e+02, -3.21937189e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 86, 'nit': 7, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-179.64407128,    0.44120487]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 69, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.79540357e+02, -3.75366677e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 84, 'nit': 24, 'warnflag': 2}
#   ConvergenceWarning)
# 97 [[-1.24 11.98]] [27.61841104]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.81666062e+02, -9.44365375e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 15, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.81653636e+02, -6.41645920e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 12, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.81680196e+02,  5.21287657e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 94, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.81666462e+02, -1.55966915e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 87, 'nit': 19, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-181.49715994,   -0.72089151]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 54, 'nit': 10, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84487608e+02, -2.58433199e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 78, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# 98 [[ 6.06 13.14]] [164.34167247]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84489978e+02, -1.24710972e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 80, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-184.40224183,   -0.38810731]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 88, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84489853e+02, -1.23629516e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 12, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84475436e+02, -7.63626433e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 59, 'nit': 11, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84149037e+02, -5.23286685e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 66, 'nit': 21, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84149772e+02, -2.92651355e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 12, 'warnflag': 2}
#   ConvergenceWarning)
# 99 [[ 5.72 10.72]] [110.22064454]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84148836e+02, -8.54256749e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 101, 'nit': 25, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84121442e+02, -1.29415791e-01]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 83, 'nit': 10, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84151588e+02,  5.25852665e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 71, 'nit': 11, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84147650e+02, -1.04644559e-02]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 69, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84150308e+02, -1.85304135e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 83, 'nit': 10, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-1.84149243e+02, -7.13440403e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 82, 'nit': 17, 'warnflag': 2}
#   ConvergenceWarning)
# 100 [[-3.9   0.58]] [187.7703265]
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.00345882e+02,  4.53066615e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 72, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.0034437e+02, -6.0966802e-04]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 110, 'nit': 25, 'warnflag': 2}
#   ConvergenceWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-2.00342573e+02, -6.93821616e-03]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 58, 'nit': 12, 'warnflag': 2}
#   ConvergenceWarning)

# %%
plot(X1_mesh, X2_mesh, Z_mesh, gp)
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:346: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "
