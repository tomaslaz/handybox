# %%
import ray
import time
import pandas as pd

# %%
@ray.remote
def f():
    time.sleep(1)
    return 1

ray.init()
results = ray.get([f.remote() for i in range(4)])
ray.shutdown()
# Out:
# 2019-07-09 13:54:45,322	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-07-09_13-54-45_321808_19593/logs.
# 2019-07-09 13:54:45,432	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:11011 to respond...
# 2019-07-09 13:54:45,547	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:39112 to respond...
# 2019-07-09 13:54:45,550	INFO services.py:806 -- Starting Redis shard with 6.87 GB max memory.
# 2019-07-09 13:54:45,563	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2019-07-09_13-54-45_321808_19593/logs.
# 2019-07-09 13:54:45,565	INFO services.py:1446 -- Starting the Plasma object store with 10.31 GB memory using /tmp.
# 2019-07-09 13:54:48,508	ERROR worker.py:1672 -- Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/ray/worker.py", line 930, in _process_task
#     self._store_outputs_in_object_store(return_object_ids, outputs)
# ...

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
ray.shutdown()
